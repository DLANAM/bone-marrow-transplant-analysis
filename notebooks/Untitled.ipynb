# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/fichier_data_set.txt')
df.head()

# %%
df.describe()
df.info()

# %%
sns.histplot(df['age'])
plt.show()
